# %%
import pandas as pd

# %%
movise_data=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\Project2\\movies_data.csv')

movise_data
# Out:
#       index  production_year       id  \
# 0         0             2006  4103791
# 1         1             2006  4022547
# 2         2             2006  3415583
# 3         3             2006  4587958
# 4         4             2006  4351263
# ...     ...              ...      ...
# 1190   1190             2017  3954779
# 1191   1191             2017  4375083
# 1192   1192             2016  4367698
# 1193   1193             2017  3342703
# 1194   1194             2017  4332562
#
#                                            title  \
# 0     Pirates of the Caribbean: Dead Man's Chest
# 1                            Night at the Museum
# 2                                           Cars
# 3                          X-Men: The Last Stand
# 4                              The Da Vinci Code
# ...                                          ...
# 1190                                Megan Leavey
# 1191                        The Greatest Showman
# 1192                                 The Founder
# ...

# %% [markdown]
# ### Case-1. Write a Python Pandas program to get the columns of the DataFrame

# %%
movise_data.columns
# Out:
# Index(['index', 'production_year', 'id', 'title', 'directors', 'genres',
#        'camera_format', 'negative_format', 'budget', 'budget_source',
#        'film_type'],
#       dtype='object')

# %% [markdown]
# ### Case-2 Write a Pandas program to get the information of the DataFrame

# %%
movise_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            1195 non-null   int64
#  1   production_year  1195 non-null   int64
#  2   id               1195 non-null   int64
#  3   title            1195 non-null   object
#  4   directors        1195 non-null   object
#  5   genres           1195 non-null   object
#  6   camera_format    1025 non-null   object
#  7   negative_format  1104 non-null   object
#  8   budget           1195 non-null   int64
#  9   budget_source    1195 non-null   object
#  10  film_type        1195 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 102.8+ KB

# %% [markdown]
# ### Case-3 Write a Pandas program to get the details of the third movie of the DataFrame

# %%
df=movise_data.loc[3]
df
# Out:
# index                                                     3
# production_year                                        2006
# id                                                  4587958
# title                                 X-Men: The Last Stand
# directors                                     Ratner, Brett
# genres             Action|Adventure|Fantasy|Sci-Fi|Thriller
# camera_format                 Panavision Cameras and Lenses
# negative_format                                       35 mm
# budget                                            210000000
# budget_source                                   the-numbers
# film_type                                                 F
# Name: 3, dtype: object

# %% [markdown]
# ### Case-4 Write a Pandas program to count the number of rows and columns of the DataFrame

# %%
movise_data.shape
# Out:
# (1195, 11)

# %% [markdown]
# ### Case-5 Write a Pandas program to get the details of the columns title and genres of the DataFrame

# %%
movise_data.loc[:,['title','genres']]
# Out:
#                                            title  \
# 0     Pirates of the Caribbean: Dead Man's Chest
# 1                            Night at the Museum
# 2                                           Cars
# 3                          X-Men: The Last Stand
# 4                              The Da Vinci Code
# ...                                          ...
# 1190                                Megan Leavey
# 1191                        The Greatest Showman
# 1192                                 The Founder
# 1193                         Battle of the Sexes
# 1194                                The Beguiled
#
#                                         genres
# 0                     Action|Adventure|Fantasy
# 1              Adventure|Comedy|Family|Fantasy
# 2                Animation|Comedy|Family|Sport
# 3     Action|Adventure|Fantasy|Sci-Fi|Thriller
# 4                             Mystery|Thriller
# ...                                        ...
# ...

# %% [markdown]
# ### Case-6 Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'

# %%
movise_data[movise_data['title']=='The Greatest Showman']
# Out:
#       index  production_year       id                 title        directors  \
# 1191   1191             2017  4375083  The Greatest Showman  Gracey, Michael
#
#                        genres  camera_format negative_format    budget  \
# 1191  Biography|Drama|Musical  Arri Alexa 65           Codex  84000000
#
#      budget_source film_type
# 1191   the-numbers         D

# %% [markdown]
# ### Case-7 Write a Pandas program to get the details of  fifth movie of the DataFrame

# %%
movise_data.loc[5]
# Out:
# index                                                              5
# production_year                                                 2006
# id                                                           4292783
# title                                               Superman Returns
# directors                                              Singer, Bryan
# genres                                       Action|Adventure|Sci-Fi
# camera_format      Panavision Genesis HD Camera, Panavision Primo...
# negative_format                                          35 mm|HDCAM
# budget                                                     232000000
# budget_source                                            the-numbers
# film_type                                                        D|F
# Name: 5, dtype: object

# %% [markdown]
# ### Case-8 Write a Pandas program to create a smaller DataFrame with a subset of all features.

# %%
movise_data.loc[1:5,['id','directors','title','genres','budget']]
# Out:
#         id                  directors                  title  \
# 1  4022547                Levy, Shawn    Night at the Museum
# 2  3415583  Lasseter, John|Ranft, Joe                   Cars
# 3  4587958              Ratner, Brett  X-Men: The Last Stand
# 4  4351263                Howard, Ron      The Da Vinci Code
# 5  4292783              Singer, Bryan       Superman Returns
#
#                                      genres     budget
# 1           Adventure|Comedy|Family|Fantasy  110000000
# 2             Animation|Comedy|Family|Sport   70000000
# 3  Action|Adventure|Fantasy|Sci-Fi|Thriller  210000000
# 4                          Mystery|Thriller  125000000
# 5                   Action|Adventure|Sci-Fi  232000000

# %% [markdown]
# ### Case-9 Write a Pandas program to display the first 10 rows of the DataFrame.

# %%
movise_data.head(10)
# Out:
#    index  production_year       id  \
# 0      0             2006  4103791
# 1      1             2006  4022547
# 2      2             2006  3415583
# 3      3             2006  4587958
# 4      4             2006  4351263
# 5      5             2006  4292783
# 6      6             2006  3688918
# 7      7             2006  3742737
# 8      8             2006  3416743
# 9      9             2006  4422776
#
#                                         title  \
# 0  Pirates of the Caribbean: Dead Man's Chest
# 1                         Night at the Museum
# 2                                        Cars
# 3                       X-Men: The Last Stand
# 4                           The Da Vinci Code
# 5                            Superman Returns
# 6                                  Happy Feet
# 7                       Ice Age: The Meltdown
# 8                               Casino Royale
# 9                    The Pursuit of Happyness
#
#                                      directors  \
# ...

# %% [markdown]
# ### Case-10 Write a Pandas program to sort the DataFrame based on release_date.

# %%
movise_data.sort_values('budget')
# Out:
#       index  production_year       id  \
# 156     156             2007  4517582
# 353     353             2009  3656467
# 460     460             2010  3728979
# 1097   1097             2017  4272940
# 165     165             2007  3630859
# ...     ...              ...      ...
# 1106   1106             2017  3801508
# 99       99             2007  4103788
# 895     895             2015  4272821
# 897     897             2015  3324830
# 499     499             2011  4103795
#
#                                             title          directors  \
# 156                                      Underdog  Du Chau, Frederik
# 353                    Ghosts of Girlfriends Past       Waters, Mark
# 460                                     Hubble 3D        Myers, Toni
# 1097                     Star Wars: The Last Jedi      Johnson, Rian
# 165                                      Fracture    Hoblit, Gregory
# ...                                           ...                ...
# ...

# %% [markdown]
# ### Case-11 Write a Pandas program to access those movies, released after 2015-

# %%
movise_data[movise_data['production_year']> 2015]
# Out:
#       index  production_year       id                       title  \
# 995     995             2016  4174476                   Rogue One
# 996     996             2016  3614660                Finding Dory
# 997     997             2016  3412075  Captain America: Civil War
# 998     998             2016  4432837     The Secret Life of Pets
# 999     999             2016  4386314             The Jungle Book
# ...     ...              ...      ...                         ...
# 1190   1190             2017  3954779                Megan Leavey
# 1191   1191             2017  4375083        The Greatest Showman
# 1192   1192             2016  4367698                 The Founder
# 1193   1193             2017  3342703         Battle of the Sexes
# 1194   1194             2017  4332562                The Beguiled
#
#                             directors                             genres  \
# 995                   Edwards, Gareth            Action|Adventure|Sci-Fi
# ...

# %% [markdown]
# ### Case-12 Write a Pandas program to sort movies on directors in descending order

# %%
movise_data.sort_values('directors',ascending=False)
# Out:
#       index  production_year       id                        title  \
# 78       78             2006  3567285       El laberinto del fauno
# 237     237             2008  3700482  Hellboy II: The Golden Army
# 978     978             2015  3466696                 Crimson Peak
# 728     728             2013  4074582                  Pacific Rim
# 1177   1177             2017  4245491                    Sleepless
# ...     ...              ...      ...                          ...
# 302     302             2009  4272468                    Star Trek
# 515     515             2011  4291293                      Super 8
# 705     705             2013  4272595      Star Trek Into Darkness
# 13       13             2006  3973646      Mission: Impossible III
# 366     366             2009  4105528                    Planet 51
#
#                                         directors  \
# 78                            del Toro, Guillermo
# 237                           del Toro, Guillermo
# ...

# %% [markdown]
# ### Case-12 Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million

# %%
movise_data[(movise_data['budget']>2000000 ) & (movise_data['budget']<5000000 )]
# Out:
#       index  production_year       id                               title  \
# 434     434             2010  4081907               Paranormal Activity 2
# 663     663             2012  4239409                            Sinister
# 684     684             2012  3221432               2016: Obama's America
# 749     749             2013  4422668                           The Purge
# 770     770             2013  3239689                     A Haunted House
# 780     780             2013  3815380          Kevin Hart: Let Me Explain
# 894     894             2014  3386406                             Boyhood
# 939     939             2015  4553964                            War Room
# 967     967             2015  4338330                   The Boy Next Door
# 1092   1092             2015  4454026  The VVitch: A New-England Folktale
#
#                            directors                   genres  \
# 434                    Williams, Tod                   Horror
# ...

# %% [markdown]
# ### Case-13 Write a Pandas program to get the film_type.

# %%
movise_data['film_type'].unique()
# Out:
# array(['F', 'D', 'D|F', 'F|U', 'U'], dtype=object)
